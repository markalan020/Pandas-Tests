# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv(
    'data/titles.csv', index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 230621

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 176477          Miss Jerry  1894
# 213694  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(titles[titles.title=='Hamlet'])
# Out:
# 18

# %%
titles[titles.title=='Hamlet']
# Out:
#          title  year
# 5969    Hamlet  1948
# 45010   Hamlet  1990
# 46365   Hamlet  1910
# 91506   Hamlet  1976
# 93696   Hamlet  1987
# 93894   Hamlet  2000
# 97869   Hamlet  1921
# 102208  Hamlet  2011
# 121837  Hamlet  1969
# 127468  Hamlet  1954
# 165217  Hamlet  1913
# 167748  Hamlet  2015
# 174816  Hamlet  2009
# 181662  Hamlet  1964
# 199837  Hamlet  1996
# 208366  Hamlet  1911
# 219855  Hamlet  1973
# 221923  Hamlet  2014

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[titles.title=='North by Northwest'])
# Out:
# 1

# %%
titles[titles.title=='North by Northwest']
# Out:
#                      title  year
# 138297  North by Northwest  1959

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles.title == "Hamlet"].sort_values('year').head(1)
# Out:
#         title  year
# 46365  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title == "Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 204540  Treasure Island  1918
# 50896   Treasure Island  1920
# 189691  Treasure Island  1934
# 96259   Treasure Island  1950
# 59186   Treasure Island  1972
# 110576  Treasure Island  1973
# 203909  Treasure Island  1985
# 178072  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles.year[titles.year == 1950])
# Out:
# 1093

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len (titles.year[titles.year == 1960])
# Out:
# 1496

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len (titles.year[(titles.year >= 1950) & (titles.year <= 1959)])
# Out:
# 12656

# %%
# other option is to use upright "|" to mean or

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title == "Batman"]
# Out:
#         title  year
# 55577  Batman  1989
# 74047  Batman  1943

# %%
titles[titles.title.str.startswith('Batman')]
# Out:
#                                         title  year
# 23950                       Batman: The Movie  1966
# 26908                           Batman Untold  2010
# 33369      Batman v Superman: Dawn of Justice  2016
# 33571                          Batman Reboots  2010
# 55577                                  Batman  1989
# 74047                                  Batman  1943
# 86429            Batman: Mask of the Phantasm  1993
# 86497   Batman: Return of the Caped Crusaders  2016
# 88594                          Batman & Robin  1997
# 103462                        Batman Revealed  2012
# 113969                       Batman: Crusader  2014
# 118856                       Batman and Robin  1949
# 146801           Batman Beyond: Rising Knight  2014
# 164316                        Batman: Anarchy  2016
# 168842                         Batman Forever  1995
# 189111                          Batman Begins  2005
# 196103                  Batman Fights Dracula  1967
# ...

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
len(cast[cast.title == "Inception"])
# Out:
# 77

# %%
cast[cast.title == "Inception"]
# Out:
#              title  year                     name     type  \
# 94333    Inception  2010     Michael (III) August    actor
# 143138   Inception  2010             Peter Basham    actor
# 176819   Inception  2010             Tom Berenger    actor
# 190249   Inception  2010                 Ken Bhan    actor
# 250191   Inception  2010           Virgile Bramly    actor
# 314663   Inception  2010            Michael Caine    actor
# 321091   Inception  2010             Earl Cameron    actor
# 361119   Inception  2010            John Ceallach    actor
# 417982   Inception  2010            Nicolas Clerc    actor
# 428199   Inception  2010           Adam (IV) Cole    actor
# 498708   Inception  2010       Jean-Michel Dagory    actor
# 569504   Inception  2010        Leonardo DiCaprio    actor
# 659835   Inception  2010            Seve Esposito    actor
# 666157   Inception  2010      Marcus (II) Everett    actor
# 682511   Inception  2010  Zachary Christopher Fay    actor
# ...

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
incep1 = cast [cast.title == "Inception"]

# %%
len(incep1[incep1.n.isnull()])
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
incep2 = cast[cast.title == "Inception"]

# %%
len(incep2[incep2.n.notnull()])
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[(cast.title == "North by Northwest") & (cast.n.notnull())].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 840374   North by Northwest  1959            Cary Grant    actor
# 3361396  North by Northwest  1959       Eva Marie Saint  actress
# 1404704  North by Northwest  1959           James Mason    actor
# 3024085  North by Northwest  1959   Jessie Royce Landis  actress
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 2923056  North by Northwest  1959  Josephine Hutchinson  actress
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast.title == "Sleuth") & (cast.year == 1972)].sort_values('n')
# Out:
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 2619278             Marguerite Wyke  5.0
# 1396572      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast.title == "Sleuth") & (cast.year == 2007)].sort_values('n')
# Out:
#           title  year                 name     type          character    n
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
len(cast[(cast.title == "Hamlet") & (cast.year == 1921)])
# Out:
# 9

# %%
cast[(cast.title == "Hamlet") & (cast.year == 1921)]
# Out:
#           title  year                    name     type         character    n
# 7438     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 442224   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 535307   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1095274  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2106367  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2289163  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2562876  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2935728  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3209199  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
len(cast[(cast.title == "Hamlet") & (cast.year == 1996)])
# Out:
# 54

# %%
cast[(cast.title == "Hamlet") & (cast.year == 1996)]
# Out:
#           title  year                    name     type  \
# 1615     Hamlet  1996              Riz Abbasi    actor
# 92106    Hamlet  1996    Richard Attenborough    actor
# 152349   Hamlet  1996     Simon Russell Beale    actor
# 206181   Hamlet  1996         David (V) Blair    actor
# 211111   Hamlet  1996           Brian Blessed    actor
# 241315   Hamlet  1996      Christopher Bowles    actor
# 250281   Hamlet  1996         Kenneth Branagh    actor
# 262368   Hamlet  1996          Richard Briers    actor
# 283598   Hamlet  1996          Michael Bryant    actor
# 307699   Hamlet  1996            Peter Bygott    actor
# 331657   Hamlet  1996       Kenneth W Caravan    actor
# 482982   Hamlet  1996           Billy Crystal    actor
# 500005   Hamlet  1996           Charles Daish    actor
# 555725   Hamlet  1996        G?rard Depardieu    actor
# 577284   Hamlet  1996          Reece Dinsdale    actor
# 582748   Hamlet  1996                Ken Dodd    actor
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
len (cast[cast.character == "Hamlet"])
# Out:
# 91

# %%
cast[cast.character == "Hamlet"]
# Out:
#                                            title  year  \
# 6003                                       Sugar  2008
# 94018                            Top of the Town  1937
# 120093                       The Sound of Spying  2014
# 154451                          Suivez cet avion  1989
# 154754                    Nous sommes les autres  2017
# 162021                               Hamlet (II)  2007
# 169062                         Un Amleto di meno  1973
# 230007                      I'll Love You Always  1935
# 250281                                    Hamlet  1996
# 264393                Le portrait de Dorian Gray  1977
# 301167                                    Hamlet  1964
# 330588                                    Amleto  1910
# 358935                               Hamlet (II)  2005
# 408007                             Hamlet A.D.D.  2014
# 416447                               Hamlet (IV)  2016
# 442218                             Sofies verden  1999
# ...

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
len(cast[cast.character == "Ophelia"])
# Out:
# 111

# %%
cast[cast.character == "Ophelia"]
# Out:
#                                            title  year  \
# 238855                The Merry Maids of Madness  2016
# 395196                            Jake Gets Paid  2009
# 453835                                Inoperable  2016
# 835461           Dogg's Hamlet, Cahoot's Macbeth  2005
# 1315145                                       11  2014
# 1525132                                   Kronos  2016
# 2052041                           Redneck Hamlet  2017
# 2353488                                    Baker  2011
# 2383774                        Queen's Encounter  2011
# 2449131                               Confession  1999
# 2469939                                 Hamlet_X  2003
# 2501586                           Khoon Ka Khoon  1935
# 2516411                       Notorious But Nice  1933
# 2516469                                 Virginia  1941
# 2534805                                 Bad Bush  2009
# 2547108                 The Caesar of 6th Street  2017
# ...

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
len(cast[cast.character == "The Dude"])
# Out:
# 18

# %%
cast[cast.character == "The Dude"]
# Out:
#                                   title  year                  name   type  \
# 261792                 The Big Lebowski  1998          Jeff Bridges  actor
# 326893               Terms & Conditions  2015           Jordan Cann  actor
# 480810                         Stranger  2000         Scott Crowell  actor
# 549887           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 588962                      Sweepstakes  1931           Mike Donlin  actor
# 607151                    Self Helpless  2010        Devin The Dude  actor
# 1051244  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1098711                   Explicit Ills  2008    Christopher Kadish  actor
# 1317786                 American Idiots  2013      Jason Loughridge  actor
# 1336484             The Winds of Autumn  1976           Steve Lyons  actor
# 1458465                         The Liq  2016        Mark Alan Meek  actor
# ...

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
len(cast.character == "The Stranger")
# Out:
# 3611212

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
len(cast[cast.name == "Sidney Poitier"])
# Out:
# 43

# %%
cast[cast.name == "Sidney Poitier"]
# Out:
#                                 title  year            name   type  \
# 1751059               A Patch of Blue  1965  Sidney Poitier  actor
# 1751060         A Piece of the Action  1977  Sidney Poitier  actor
# 1751061           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1751062               A Warm December  1973  Sidney Poitier  actor
# 1751063             All the Young Men  1960  Sidney Poitier  actor
# 1751064                Band of Angels  1957  Sidney Poitier  actor
# 1751065             Blackboard Jungle  1955  Sidney Poitier  actor
# 1751066                  Brother John  1971  Sidney Poitier  actor
# 1751067         Buck and the Preacher  1972  Sidney Poitier  actor
# 1751068      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1751069                Duel at Diablo  1966  Sidney Poitier  actor
# 1751070              Edge of the City  1957  Sidney Poitier  actor
# 1751071               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
len(cast[cast.name == "Judi Dench"])
# Out:
# 55

# %%
cast[cast.name == "Judi Dench"].sort_values('year')
# Out:
#                                                      title  year        name  \
# 2703504                                   The Third Secret  1964  Judi Dench
# 2703459                                  A Study in Terror  1965  Judi Dench
# 2703469                               He Who Rides a Tiger  1965  Judi Dench
# 2703466                                Four in the Morning  1965  Judi Dench
# 2703457                          A Midsummer Night's Dream  1968  Judi Dench
# 2703478                                             Luther  1974  Judi Dench
# 2703463                                          Dead Cert  1974  Judi Dench
# 2703509                                           Wetherby  1985  Judi Dench
# 2703458                                 A Room with a View  1985  Judi Dench
# 2703498                           The Angelic Conversation  1985  Judi Dench
# 2703455                              84 Charing Cross Road  1987  Judi Dench
# ...

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast.n == 2) & 
     (cast.name == 'Cary Grant') & 
     (cast.year // 10 == 194)].sort_values ('year')
# Out:
#                    title  year        name   type    character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 840381    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %%
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast [(cast.n == 1) &
     (cast.year // 10 == 194) &
     (cast.name == "Cary Grant")].sort_values('year')
# Out:
#                                        title  year        name   type  \
# 840397               The Howards of Virginia  1940  Cary Grant  actor
# 840353                       His Girl Friday  1940  Cary Grant  actor
# 840399                The Philadelphia Story  1940  Cary Grant  actor
# 840386                             Suspicion  1941  Cary Grant  actor
# 840401                  The Talk of the Town  1942  Cary Grant  actor
# 840377                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 840344                     Destination Tokyo  1943  Cary Grant  actor
# 840369                             Mr. Lucky  1943  Cary Grant  actor
# 840370                             Mr. Lucky  1943  Cary Grant  actor
# 840378                      Once Upon a Time  1944  Cary Grant  actor
# 840336                  Arsenic and Old Lace  1944  Cary Grant  actor
# 840373             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
len(cast[(cast.year // 10 == 195) & (cast.type == 'actor')])
# Out:
# 154727

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
len(cast[(cast.year // 10 == 195)&(cast.type == 'actress')])
# Out:
# 56259

# %%
c = cast
c = c[c.year // 10 == 195]
c = c[c.type == 'actress']
len(c)
# Out:
# 56259

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
len(cast[(cast.n == 1)&(cast.year <= 1980)])
# Out:
# 63924

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
len (cast[(cast.n != 1)&(cast.year <=1980)])
# Out:
# 1094780

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
len(cast[(cast.year <= 1980)&(cast.n.isnull())])
# Out:
# 438086

# %%
import matplotlib.pyplot as plt
plt.plot(titles.year.value_counts().sort_index())
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
c = cast
c = c[c.character == "Kermit the Frog"]
#plt.plot(c[c.character == "Kermit the Frog"])
#plt.xvalue('year')
#plt.yvalue('n')
#plt.show
c.plot(x='year', y='n', kind= 'scatter')
